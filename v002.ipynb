# %%
import numpy as np
import pandas as pd

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn import metrics
import warnings
warnings.filterwarnings('ignore')

# !pip install openpyxl
# Out:
# <style>.container { width:100% !important; }</style>
# Requirement already satisfied: openpyxl in /opt/anaconda3/lib/python3.9/site-packages (3.0.10)
# Requirement already satisfied: et-xmlfile in /opt/anaconda3/lib/python3.9/site-packages (from openpyxl) (1.1.0)

# %%
data = pd.read_excel("Case_Dataset.xlsx")

# %%
df = data.copy()

# %%
df.head()
# Out:
#     SurgDate  DOW  T - 28  T - 21  T - 14  T - 13  T - 12  T - 11  T - 10  \
# 0 2011-10-10  Mon      38      45      60      63      65      70      73
# 1 2011-10-11  Tue      35      47      65      68      78      82      82
# 2 2011-10-12  Wed      26      43      54      62      72      72      72
# 3 2011-10-13  Thu      28      48      65      70      72      72      72
# 4 2011-10-14  Fri      31      40      50      50      50      54      62
#
#    T - 9  T - 8  T - 7  T - 6  T - 5  T - 4  T - 3  T - 2  T - 1  Actual
# 0     73     73     80     84     89     94     98    100    104     106
# 1     82     86     89     92     95     99     99     99    114     121
# 2     74     87     94     96    101    102    102    106    114     126
# 3     82     87     91     94     94     94     97     98    103     114
# 4     68     71     73     73     73     78     83     87     94     106

# %%
df.head(50)
# Out:
#      SurgDate  DOW  T - 28  T - 21  T - 14  T - 13  T - 12  T - 11  T - 10  \
# 0  2011-10-10  Mon      38      45      60      63      65      70      73
# 1  2011-10-11  Tue      35      47      65      68      78      82      82
# 2  2011-10-12  Wed      26      43      54      62      72      72      72
# 3  2011-10-13  Thu      28      48      65      70      72      72      72
# 4  2011-10-14  Fri      31      40      50      50      50      54      62
# 5  2011-10-17  Mon      41      56      65      69      72      73      77
# 6  2011-10-18  Tue      44      55      69      74      79      83      83
# 7  2011-10-19  Wed      32      40      62      66      71      73      73
# 8  2011-10-20  Thu      33      44      62      66      67      67      79
# 9  2011-10-21  Fri      20      32      48      48      48      47      52
# 10 2011-10-24  Mon      32      44      55      59      61      66      69
# 11 2011-10-25  Tue      40      51      61      65      70      70      70
# 12 2011-10-26  Wed      26      38      54      63      65      65      65
# 13 2011-10-27  Thu      34      54      74      75      75      75      78
# 14 2011-10-28  Fri      32      39      61      61      61      61      64
# 15 2011-10-31  Mon      29      41      61      60      62      65      68
# 16 2011-11-01  Tue      35      56      73      76      81      84      85
# 17 2011-11-02  Wed      27      42      66      68      71      71      71
# 18 2011-11-03  Thu      40      60      78      81      81      81      84
# 19 2011-11-04  Fri      25      43      63      63      63      64      67
# 20 2011-11-07  Mon      35      47      62      69      68      75      77
# 21 2011-11-08  Tue      39      51      67      72      76      83      83
# 22 2011-11-09  Wed      26      44      62      63      68      68      68
# 23 2011-11-10  Thu      44      66      92      98      98      98     101
# 24 2011-11-11  Fri      32      46      65      65      65      69      72
# 25 2011-11-14  Mon      42      54      66      69      74      76      79
# 26 2011-11-15  Tue      52      70      92      95     102     106     106
# 27 2011-11-16  Wed      43      55      65      75      81      81      82
# 28 2011-11-17  Thu      47      56      77      80      80      80      85
# 29 2011-11-18  Fri      26      42      59      57      57      58      61
# 30 2011-11-21  Mon      42      51      59      60      64      64      72
# 31 2011-11-22  Tue      44      56      66      69      74      81      81
# 32 2011-11-23  Wed      18      29      43      43      47      47      47
# 33 2011-11-25  Fri       0       0       1       1       1       1       2
# 34 2011-11-28  Mon      41      64      74      80      81      83      93
# 35 2011-11-29  Tue      48      60      77      77      82      85      86
# 36 2011-11-30  Wed      36      53      75      80      84      84      84
# 37 2011-12-01  Thu      48      53      77      84      84      84      87
# 38 2011-12-02  Fri      31      42      61      62      62      63      68
# 39 2011-12-05  Mon      43      53      70      74      76      76      75
# 40 2011-12-06  Tue      35      42      66      73      73      73      73
# 41 2011-12-07  Wed      35      50      61      62      62      62      62
# 42 2011-12-08  Thu      42      64      75      75      75      75      79
# 43 2011-12-09  Fri      49      67      76      76      76      78      80
# 44 2011-12-12  Mon      40      53      66      68      75      77      81
# 45 2011-12-13  Tue      46      62      69      76      82      88      88
# 46 2011-12-14  Wed      56      73      84      85      89      89      89
# 47 2011-12-15  Thu      45      65      87      93      94      94      98
# 48 2011-12-16  Fri      48      63      85      85      85      89      90
# 49 2011-12-19  Mon      50      62      69      69      72      82      84
#
#     T - 9  T - 8  T - 7  T - 6  T - 5  T - 4  T - 3  T - 2  T - 1  Actual
# 0      73     73     80     84     89     94     98    100    104     106
# 1      82     86     89     92     95     99     99     99    114     121
# 2      74     87     94     96    101    102    102    106    114     126
# 3      82     87     91     94     94     94     97     98    103     114
# 4      68     71     73     73     73     78     83     87     94     106
# 5      78     78     80     86     85     86     92     96    102     111
# 6      83     93     92     96    103    105    105    107    114     122
# 7      84     86     87     89     96     96     96    102    119     127
# 8      77     88     90     98     98     98    105    111    118     116
# 9      55     59     61     61     61     69     72     70     88      99
# 10     69     69     69     74     77     83     85     86     92      99
# 11     70     75     80     83     89     94     96     96    100     102
# 12     68     74     81     89     94     94     94    103    108     117
# 13     80     85     91     91     94     94     96    104    116     133
# 14     69     72     74     74     74     77     84     83     98     115
# 15     68     68     73     78     82     84     91     95    105     105
# 16     85     94     97     97     97    104    105    105    119     112
# 17     75     82     87     99    100    100    100    109    115     121
# 18     89     93    101    102    102    102    105    112    120     126
# 19     71     77     78     78     78     79     79     91     95     101
# 20     77     77     78     81     84     89     92     95     99     110
# 21     83     90     98    101    104    108    108    108    121     129
# 22     74     82     85     97     99    100    101    106    119     122
# 23    107    109    118    121    121    121    127    126    133     145
# 24     73     81     81     81     81     84     91    102    113     120
# 25     79     79     83     90    103    106    115    116    123     132
# 26    106    108    108    111    116    116    117    118    118     131
# 27     85     93    100    105    110    110    110    112    121     127
# 28     90     95    103    106    106    106    107    113    124     134
# 29     70     78     86     86     86     89     92    104    119     127
# 30     72     72     76     83     91     93    106    109    120     130
# 31     81     90     95    104    108    112    112    113    126     127
# 32     49     54     58     60     63     63     63     70     83      95
# 33      2      2      3      3      3      3      4      7     12      16
# 34     96     96    102    106    113    116    119    119    125     138
# 35     86     92     96    102    103    103    103    106    111     115
# 36     86     88     92     93     93     93     93    100    111     124
# 37     90     97     98     98     98     98     97     99    112     124
# Corr(T-3,Actual)=0.913
# Corr(T-7,Actual)=0.896
# Corr(T-14,Actual)=0.801
# Corr(T-21,Actual)=0.702
# Corr(T-28,Actual)=0.608

# Average number of surgery cases increases  as we move closer to actual day
# As the gap from surgery day increase, the correlation decreases
# From the correlation matrix, almost all the correlations are significantly high.

# %%
# Average of actual surgery is 116 with standard deviation of 17.63

# %%
# Validating for T - 1
df.groupby('DOW')['T - 1'].mean(), df.groupby('DOW')['T - 1'].std()
# Out:
# (DOW
#  Fri     97.428571
#  Mon    110.787234
#  Thu    117.583333
#  Tue    114.020408
#  Wed    110.416667
#  Name: T - 1, dtype: float64,
#  DOW
#  Fri    25.922159
#  Mon    18.863279
#  Thu    10.394011
#  Tue    10.296621
#  Wed    11.100764
#  Name: T - 1, dtype: float64)

# %% [raw]
# - Friday her zaman en dusuk ortalamaya sahip hafta ici gunu. Ayni zamanda en yuksek varyansin gerceklestigi gun de friday olarak gozukmekte. Grafikte de gorebiliriz.
#
# - Thursday de friday kiyasla haftanin en yogun ameliyat gerceklesen gunu. *Burada persembe gunleri icin ekstra bir is cikmis olabilir yada cumaya birakmadan isleri persembeden hallediyor olabilirler.

# %%
df['DOW'].value_counts()
# Out:
# Tue    49
# Fri    49
# Wed    48
# Thu    48
# Mon    47
# Name: DOW, dtype: int64

# %%
# Trend of Number of Surgeries performed by Day of Week
df2 = df[['DOW', 'Actual']]
ax = sns.barplot(x='DOW',y='Actual', data=df, palette='coolwarm')

# %%
sns.boxplot(x='DOW',y='Actual', data=df, palette='coolwarm')
# Out:
# <AxesSubplot:xlabel='DOW', ylabel='Actual'>

# %%
# Fridays have lowest number of surgeries which may be indicate surgeon preferences
# Thursdays have lowest number of surgeries
# Alternatively, the high number of surgeries on Thursday might be due to add-on cases

# %%
test = df.loc[1:242, 'T - 28':'T - 1']
mean = test.mean()
maximum = test.max()
std = test.std()

# %%
a = pd.DataFrame(mean)
b = pd.DataFrame(maximum)
c = pd.DataFrame(std)
new = pd.concat([a,b,c], axis = 1)
new.columns = ['Mean', 'Maximum', 'Standard Deviation']
new
# Out:
#               Mean  Maximum  Standard Deviation
# T - 28   34.245833       57            9.404107
# T - 21   47.250000       73           11.343809
# T - 14   64.458333       93           13.521033
# T - 13   67.837500       99           14.227186
# T - 12   70.525000      102           14.899924
# T - 11   72.375000      106           15.001290
# T - 10   74.954167      106           15.127699
# T - 9    78.062500      112           15.082765
# T - 8    82.375000      113           15.615711
# T - 7    86.025000      118           16.118008
# T - 6    89.291667      121           16.943863
# T - 5    92.104167      121           17.405621
# T - 4    94.691667      124           17.504713
# T - 3    97.370833      127           17.626530
# T - 2   101.170833      131           17.583512
# T - 1   110.033333      139           17.817970

# %% [markdown]
# # ANOVA Testing

# %%
df.columns
# Out:
# Index(['SurgDate', 'DOW', 'T - 28', 'T - 21', 'T - 14', 'T - 13', 'T - 12',
#        'T - 11', 'T - 10', 'T - 9', 'T - 8', 'T - 7', 'T - 6', 'T - 5',
#        'T - 4', 'T - 3', 'T - 2', 'T - 1', 'Actual'],
#       dtype='object')

# %%
# !pip install statsmodels
import statsmodels.api as sm
from statsmodels.formula.api import ols

model = ols('Actual ~ DOW', data=df).fit()
aov_table = sm.stats.anova_lm(model, typ=2)
aov_table
# Out:
# Requirement already satisfied: statsmodels in /opt/anaconda3/lib/python3.9/site-packages (0.13.2)
# Requirement already satisfied: packaging>=21.3 in /opt/anaconda3/lib/python3.9/site-packages (from statsmodels) (21.3)
# Requirement already satisfied: patsy>=0.5.2 in /opt/anaconda3/lib/python3.9/site-packages (from statsmodels) (0.5.2)
# Requirement already satisfied: pandas>=0.25 in /opt/anaconda3/lib/python3.9/site-packages (from statsmodels) (1.4.1)
# Requirement already satisfied: numpy>=1.17 in /opt/anaconda3/lib/python3.9/site-packages (from statsmodels) (1.22.3)
# Requirement already satisfied: scipy>=1.3 in /opt/anaconda3/lib/python3.9/site-packages (from statsmodels) (1.7.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/anaconda3/lib/python3.9/site-packages (from packaging>=21.3->statsmodels) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.25->statsmodels) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.25->statsmodels) (2021.3)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.9/site-packages (from patsy>=0.5.2->statsmodels) (1.16.0)
#                 sum_sq     df         F    PR(>F)
# DOW        8909.054042    4.0  8.002734  0.000005
# Residual  65681.825626  236.0       NaN       NaN

# %%
# Null Hypothesis: Total surgical case volume does not differ based on the day of week
# Alternative Hypothesis: Total surgical case volume differs based on the day of week

# Perform multiple pairwise comparison (Tukey HSD)
# Tukey test results will provide the difference between combination of any two days

from statsmodels.stats.multicomp import pairwise_tukeyhsd
tukey = pairwise_tukeyhsd(endog=df['Actual'], groups=df['DOW'], alpha=0.05)
print(tukey)
# Out:
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =====================================================
# group1 group2 meandiff p-adj   lower    upper  reject
# -----------------------------------------------------
#    Fri    Mon  10.6431  0.017   1.2798 20.0063   True
#    Fri    Thu  18.4711    0.0   9.1577 27.7844   True
#    Fri    Tue  13.4694 0.0008   4.2042 22.7346   True
#    Fri    Wed  11.4294 0.0077   2.1161 20.7428   True
#    Mon    Thu    7.828 0.1529  -1.5829 17.2389  False
#    Mon    Tue   2.8263 0.9212   -6.537 12.1896  False
#    Mon    Wed   0.7863 0.9994  -8.6246 10.1972  False
#    Thu    Tue  -5.0017 0.5789 -14.3151  4.3117  False
#    Thu    Wed  -7.0417 0.2376 -16.4029  2.3196  False
#    Tue    Wed    -2.04 0.9747 -11.3533  7.2734  False
# -----------------------------------------------------

# %% [markdown]
# # Models :

# %% [markdown]
# ## Model 1 : Linear Regression Model :

# %% [raw]
# Data Cleaning: Removed outliers to make the dependent variable uniformly distributed
#
# Regression Equation:
#
# x = a1T-28 + a2T-21 + ..... + axT-1 + axDOW

# %%
df1 = df.drop(columns = ['SurgDate', 'DOW'])

from scipy import stats
df1 = df1[(np.abs(stats.zscore(df1)) < 3).all(axis=1)]

# %% [markdown]
# ## Baseline model :

# %%
# x = df1[['T - 28', 'T - 21', 'T - 14', 'T - 13', 'T - 12', 'T - 11', 'T - 10', 'T - 9', 'T - 8', 
#          'T - 7', 'T - 6', 'T - 5', 'T - 4', 'T - 3', 'T - 2']]
# y = df1[['Actual']]

# %%
x = df[['T - 3', 'T - 2', 'T - 1']]
y = df[['Actual']]

# %%
# 1. With sklearn
from sklearn import linear_model
import statsmodels.api as sm
regr = linear_model.LinearRegression()
regr.fit(x, y)

print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)

# T-11 strong negative
# Out:
# Intercept:
#  [10.96140663]
# Coefficients:
#  [[-0.14256711  0.15693554  0.94016588]]

# %%
# 2. With statsmodels
 
model = sm.OLS(y, x).fit()
predictions = model.predict(x) 
 
print_model = model.summary()
print(print_model)
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                 Actual   R-squared (uncentered):                   0.998
# Model:                            OLS   Adj. R-squared (uncentered):              0.998
# Method:                 Least Squares   F-statistic:                          4.535e+04
# Date:                Sat, 11 Jun 2022   Prob (F-statistic):                        0.00
# Time:                        07:53:45   Log-Likelihood:                         -725.88
# No. Observations:                 241   AIC:                                      1458.
# Df Residuals:                     238   BIC:                                      1468.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# T - 3         -0.1908      0.099     -1.926      0.055      -0.386       0.004
# T - 2          0.1453      0.127      1.144      0.254      -0.105       0.395
# T - 1          1.0908      0.069     15.891      0.000       0.956       1.226
# ==============================================================================
# Omnibus:                        4.980   Durbin-Watson:                   1.916
# Prob(Omnibus):                  0.083   Jarque-Bera (JB):                4.972
# Skew:                           0.245   Prob(JB):                       0.0833
# Kurtosis:                       3.506   Cond. No.                         89.7
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#Fitting Simple Linear regression data model
from sklearn.linear_model import LinearRegression
regressorObject=LinearRegression()
regressorObject.fit(x,y)

#predict number of surgeries for the data set
predict = df1.loc[2:242, 'T - 3':'T - 1']
y_pred_test_data=regressorObject.predict(predict)

# %%
Predicted = pd.DataFrame(y_pred_test_data, columns = ['Predicted'])

# %%
result = pd.concat([df, Predicted], ignore_index=True, axis=1)
result.columns = ['SurgDate', 'DOW', 'T - 28', 'T - 21', 'T - 14', 'T - 13', 'T - 12', 'T - 11',' T - 10', 'T - 9',
                  'T - 8', 'T - 7', 'T - 6', 'T - 5', 'T - 4', 'T - 3', 'T - 2', 'T - 1', 'Actual', 'Predicted']
result['Predicted'] = round(result['Predicted'])

# %%
final = result.dropna()
final.tail(10)
# Out:
#       SurgDate  DOW  T - 28  T - 21  T - 14  T - 13  T - 12  T - 11   T - 10  \
# 225 2012-08-23  Thu      41      48      89      98      98      98      100
# 226 2012-08-24  Fri      29      34      67      67      67      67       75
# 227 2012-08-27  Mon      40      44      66      69      79      82       85
# 228 2012-08-28  Tue      34      56      69      84      91      94       94
# 229 2012-08-29  Wed      36      57      76      81      87      87       87
# 230 2012-08-30  Thu      29      59      86      88      88      88       97
# 231 2012-08-31  Fri      19      38      58      58      58      62       68
# 232 2012-09-04  Tue      23      36      51      57      66      72       73
# 233 2012-09-05  Wed      27      37      47      54      60      60       60
# 234 2012-09-06  Thu      23      42      70      80      81      81       87
#
#      T - 9  T - 8  T - 7  T - 6  T - 5  T - 4  T - 3  T - 2  T - 1  Actual  \
# 225    110    113    117    112    112    113    114    119    129     127
# 226     91     95    104    104    104    108    115    119    126     126
# 227     85     86     92     98    107    109    111    116    123     127
# 228     94     99    103    110    119    124    125    128    139     139
# 229     92     99    101    102    104    103    103    107    114     125
# 230    102    105    106    112    113    113    113    115    124     126
# 231     71     80     86     86     86     94     93     99    116     124
# 232     73     74     80     84     92    105    106    106    116     114
# 233     61     70     70     74     81     81     82     85     95     103
# 234     86     93     99    105    105    105    106    108    119     126
#
#      Predicted
# 225      122.0
# 226      122.0
# 227      102.0
# 228      125.0
# 229      100.0
# 230      117.0
# 231      105.0
# 232      121.0
# 233      113.0
# 234      108.0

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
y_actual = final['Actual']
y_predicted = final['Predicted']
rms = sqrt(mean_squared_error(y_actual, y_predicted))
rms
# Out:
# 20.653782302625718

# %%
y = final['Actual']
yhat = final['Predicted']
d = y - yhat
mse_f = np.mean(d**2)
mae_f = np.mean(abs(d))
rmse_f = np.sqrt(mse_f)
r2_f = 1-(sum(d**2)/sum((y-np.mean(y))**2))

print("Results by manual calculation:")
print("MAE:",mae_f)
print("MSE:", mse_f)
print("RMSE:", rmse_f)
print("R-Squared:", r2_f)
# Out:
# Results by manual calculation:
# MAE: 14.953191489361702
# MSE: 426.5787234042553
# RMSE: 20.653782302625718
# R-Squared: -0.3528353839078937

# %% [markdown]
# # Predicting results for 3 days before the Surgery Date

# %%
x = df1[['T - 28', 'T - 21', 'T - 14', 'T - 13', 'T - 12', 'T - 11', 'T - 10', 'T - 9', 'T - 8', 'T - 7', 
         'T - 6', 'T - 5', 'T - 4']]
y = df1[['Actual']]

# %%
# 1. With sklearn
from sklearn import linear_model
import statsmodels.api as sm
regr = linear_model.LinearRegression()
regr.fit(x, y)

print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)

# T-11 strong negative
# Out:
# Intercept:
#  [40.42147371]
# Coefficients:
#  [[-0.0640146   0.05590182  0.12707909 -0.06299405  0.24426308 -0.71805695
#    0.09246963  0.26304515  0.13928967  0.18765895 -0.31579327  0.22184926
#    0.62816948]]

# %%
# 2. With statsmodels
 
model = sm.OLS(y, x).fit()
predictions = model.predict(x) 
 
print_model = model.summary()
print(print_model)
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                 Actual   R-squared (uncentered):                   0.996
# Model:                            OLS   Adj. R-squared (uncentered):              0.995
# Method:                 Least Squares   F-statistic:                              3829.
# Date:                Sat, 11 Jun 2022   Prob (F-statistic):                   6.41e-255
# Time:                        07:59:22   Log-Likelihood:                         -827.42
# No. Observations:                 237   AIC:                                      1681.
# Df Residuals:                     224   BIC:                                      1726.
# Df Model:                          13
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# T - 28        -0.1030      0.131     -0.787      0.432      -0.361       0.155
# T - 21         0.0731      0.139      0.526      0.599      -0.201       0.347
# T - 14         0.2783      0.203      1.369      0.172      -0.122       0.679
# T - 13         0.1285      0.310      0.415      0.679      -0.482       0.739
# T - 12        -0.2263      0.353     -0.641      0.522      -0.922       0.470
# T - 11        -0.6265      0.342     -1.830      0.069      -1.301       0.048
# T - 10        -0.0776      0.270     -0.287      0.774      -0.611       0.455
# T - 9          0.4263      0.247      1.726      0.086      -0.060       0.913
# T - 8          0.1689      0.251      0.672      0.502      -0.326       0.664
# T - 7          0.5228      0.294      1.775      0.077      -0.058       1.103
# T - 6         -0.7779      0.315     -2.470      0.014      -1.398      -0.157
# T - 5          0.1943      0.301      0.646      0.519      -0.398       0.787
# T - 4          1.2205      0.200      6.117      0.000       0.827       1.614
# ==============================================================================
# Omnibus:                        1.792   Durbin-Watson:                   1.830
# Prob(Omnibus):                  0.408   Jarque-Bera (JB):                1.698
# Skew:                           0.207   Prob(JB):                        0.428
# Kurtosis:                       2.984   Cond. No.                         262.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#Fitting Simple Linear regression data model
from sklearn.linear_model import LinearRegression
regressorObject=LinearRegression()
regressorObject.fit(x,y)

#predict number of surgeries for the data set
predict = df1.loc[2:242, 'T - 28':'T - 4']
y_pred_test_data=regressorObject.predict(predict)

# %%
Predicted = pd.DataFrame(y_pred_test_data, columns = ['Predicted'])

# %%
result2 = pd.concat([df, Predicted], ignore_index=True, axis=1)
result2.columns = ['SurgDate', 'DOW', 'T - 28', 'T - 21', 'T - 14', 'T - 13', 'T - 12', 'T - 11',' T - 10', 'T - 9',
                  'T - 8', 'T - 7', 'T - 6', 'T - 5', 'T - 4', 'T - 3', 'T - 2', 'T - 1', 'Actual', 'Predicted']
result2['Predicted'] = round(result2['Predicted'])

# %%
final2 = result2.dropna()

# %%
round(result['Actual'].mean()), round(result2['Predicted'].mean())

# Average Daily Error: ~2 Surgeries
# Out:
# (116, 118)

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
y_actual = final2['Actual']
y_predicted = final2['Predicted']
rms = sqrt(mean_squared_error(y_actual, y_predicted))
rms
# Out:
# 19.41955583776751

# %%
y = final2['Actual']
yhat = final2['Predicted']
d = y - yhat
mse_f = np.mean(d**2)
mae_f = np.mean(abs(d))
rmse_f = np.sqrt(mse_f)
r2_f = 1-(sum(d**2)/sum((y-np.mean(y))**2))

print("Results by manual calculation:")
print("MAE:",mae_f)
print("MSE:", mse_f)
print("RMSE:", rmse_f)
print("R-Squared:", r2_f)
# Out:
# Results by manual calculation:
# MAE: 13.987234042553192
# MSE: 377.11914893617023
# RMSE: 19.41955583776751
# R-Squared: -0.19598118855684277

# %% [markdown]
# # Predicting results for 7 days before the surgery date

# %%
x = df1[['T - 28', 'T - 21', 'T - 14', 'T - 13', 'T - 12', 'T - 11', 'T - 10', 'T - 9', 'T - 8']]
y = df1[['Actual']]

# %%
#Fitting Simple Linear regression data model
from sklearn.linear_model import LinearRegression
regressorObject=LinearRegression()
regressorObject.fit(x,y)

#predict number of surgeries for the data set
predict = df1.loc[2:242, 'T - 28':'T - 8']
y_pred_test_data=regressorObject.predict(predict)

# %%
Predicted = pd.DataFrame(y_pred_test_data, columns = ['Predicted'])

# %%
result3 = pd.concat([df, Predicted], ignore_index=True, axis=1)
result3.columns = ['SurgDate', 'DOW', 'T - 28', 'T - 21', 'T - 14', 'T - 13', 'T - 12', 'T - 11',' T - 10', 'T - 9',
                  'T - 8', 'T - 7', 'T - 6', 'T - 5', 'T - 4', 'T - 3', 'T - 2', 'T - 1', 'Actual', 'Predicted']
result3['Predicted'] = round(result3['Predicted'])

# %%
final3 = result3.dropna()

# %%
round(result['Actual'].mean()), round(final3['Predicted'].mean())

# Average Daily Error: ~2 Surgeries
# Out:
# (116, 118)

# %%
y = final3['Actual']
yhat = final3['Predicted']
d = y - yhat
mse_f = np.mean(d**2)
mae_f = np.mean(abs(d))
rmse_f = np.sqrt(mse_f)
r2_f = 1-(sum(d**2)/sum((y-np.mean(y))**2))

print("Results by manual calculation:")
print("MAE:",mae_f)
print("MSE:", mse_f)
print("RMSE:", rmse_f)
print("R-Squared:", r2_f)
# Out:
# Results by manual calculation:
# MAE: 13.565957446808511
# MSE: 375.6085106382979
# RMSE: 19.380622039508893
# R-Squared: -0.19119040826349143

# %%
plt.figure(figsize=[15,8])
plt.grid(True)
plt.plot(result['Actual'],label='Actual')
plt.plot(result['Predicted'],label='Predicted')
# plt.plot(df['SMA_4'],label='SMA 4 Months')
plt.legend(loc=2)
